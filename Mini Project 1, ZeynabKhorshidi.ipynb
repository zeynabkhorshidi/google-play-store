# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 align="center">Machine Learning in Python</h1>
#     <h3 align="center">Mini Project1</h3>
# </div>

# %% [markdown]
# <img src = "https://www.cyclonis.com/images/2020/03/googleplay.jpg" width=50%>

# %% [markdown]
# <div style="background-color:yellow;">
#     <h1></h1>
#     <h2 align="center"><ins><mark>Zeynab Khorshidi</mark></ins></h2>
#     <h3 align="center"><mark>Mini Project 1</mark></h3>
#     <h4 align="center"><a href="https://play.google.com/">Google Play</a>
#     <h5></h5>
# </div>

# %% [markdown]
# <div style="background-color:pink;">
#     <h1 align="center"><ins>Importing the libraries</ins></h1>
# </div>

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <div style="background-color:orange;">
#     <h1 align="center"><ins>Load and Prepare Data</ins></h1>
# </div>

# %%
googleplay_data = pd.read_csv(r"E:\Course\utech AI\ML\Project\Google play\googleplaystore.csv")

# %% [markdown]
# ## EDA (Use Pandas)

# %% [markdown]
# <div style="background-color:green;">
#     <h1 align="center"><ins>get google play's data Type</ins></h1>
# </div>

# %%
type(googleplay_data)
# Out:
# pandas.core.frame.DataFrame

# %%
googleplay_data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# <div style="background-color:purple;">
#     <h1 align="center"><ins>get head of list</ins></h1>
# </div>

# %%
googleplay_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# <div style="background-color:brown;">
#     <h1 align="center"><ins>get tail of list</ins></h1>
# </div>

# %%
googleplay_data.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# <div style="background-color:pink;">
#     <h1></h1>
#     <h2 align="center"><ins><mark>GOOGLE PLAY</mark></ins></h2>
#     <h3></h3>
# </div>

# %% [markdown]
# <img src = "https://cdn01.zoomit.ir/ex/Cover/0d82d7410c77c4deb97cdfff0a9efc72_XL.jpg">

# %% [markdown]
# <div style="background-color:African violet;">
#     <h1 align="center"><ins>get shape of list</ins></h1>
# </div>

# %%
googleplay_data.shape
# Out:
# (10841, 13)

# %% [markdown]
# <div style="background-color:light blue;">
#     <h1 align="center"><ins>get columns of list</ins></h1>
# </div>

# %%
googleplay_data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# <div style="background-color:orange;">
#     <h1 align="center"><ins>get data types of list</ins></h1>
# </div>

# %%
googleplay_data.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# <div style="background-color:yellow;">
#     <h1 align="center"><ins>get data's info</ins></h1>
# </div>

# %%
googleplay_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# <div style="background-color:red;">
#     <h1 align="center"><ins>Select specific rows and columns</ins></h1>
# </div>

# %%
googleplay_data['Rating'][0:7]
# Out:
# 0    4.1
# 1    3.9
# 2    4.7
# 3    4.5
# 4    4.3
# 5    4.4
# 6    3.8
# Name: Rating, dtype: float64

# %%
googleplay_data.Rating[0:7]
# Out:
# 0    4.1
# 1    3.9
# 2    4.7
# 3    4.5
# 4    4.3
# 5    4.4
# 6    3.8
# Name: Rating, dtype: float64

# %% [markdown]
# <div style="background-color:pink;">
#     <h1 align="center"><ins>Select columns based on multiple titles</ins></h1>
# </div>

# %%
googleplay_data[['Rating','Size','Android Ver']][10:20]
# Out:
#     Rating  Size   Android Ver
# 10     4.4   28M    4.1 and up
# 11     4.4   12M    4.0 and up
# 12     4.2   20M    4.1 and up
# 13     4.6   21M    4.4 and up
# 14     4.4   37M    2.3 and up
# 15     3.2  2.7M    4.2 and up
# 16     4.7  5.5M    4.1 and up
# 17     4.5   17M    2.3 and up
# 18     4.3   39M  4.0.3 and up
# 19     4.6   31M    4.1 and up

# %% [markdown]
# <div style="background-color:orange;">
#     <h1 align="center"><ins>Print Unique data across the column and their number</ins></h1>
# </div>

# %%
googleplay_data['Type'].value_counts()
# Out:
# Free    10039
# Paid      800
# 0           1
# Name: Type, dtype: int64

# %% [markdown]
# <div style="background-color:blue;">
#     <h1 align="center"><ins>normalize data</ins></h1>
# </div>

# %%
googleplay_data['Type'].value_counts(normalize=True)*100
# Out:
# Free    92.610701
# Paid     7.380074
# 0        0.009225
# Name: Type, dtype: float64

# %% [markdown]
# <div style="background-color:yellow;">
#     <h1 align="center"><ins>type of data Separation with Category</ins></h1>
# </div>

# %%
pd.crosstab( googleplay_data.Type, googleplay_data.Category)
# Out:
# Category  1.9  ART_AND_DESIGN  AUTO_AND_VEHICLES  BEAUTY  BOOKS_AND_REFERENCE  \
# Type
# 0           1               0                  0       0                    0
# Free        0              62                 82      53                  203
# Paid        0               3                  3       0                   28
#
# Category  BUSINESS  COMICS  COMMUNICATION  DATING  EDUCATION  ...  \
# Type                                                          ...
# 0                0       0              0       0          0  ...
# Free           446      60            360     227        152  ...
# Paid            14       0             27       7          4  ...
#
# Category  PERSONALIZATION  PHOTOGRAPHY  PRODUCTIVITY  SHOPPING  SOCIAL  \
# Type
# 0                       0            0             0         0       0
# Free                  309          313           396       258     292
# Paid                   83           22            28         2       3
#
# ...

# %% [markdown]
# <div style="background-color:green;">
#     <h1 align="center"><ins>Normalize data by row</ins></h1>
# </div>

# %%
pd.crosstab( googleplay_data.Type, googleplay_data.Category, normalize = "index")*100
# Out:
# Category    1.9  ART_AND_DESIGN  AUTO_AND_VEHICLES    BEAUTY  \
# Type
# 0         100.0        0.000000           0.000000  0.000000
# Free        0.0        0.617591           0.816814  0.527941
# Paid        0.0        0.375000           0.375000  0.000000
#
# Category  BOOKS_AND_REFERENCE  BUSINESS    COMICS  COMMUNICATION    DATING  \
# Type
# 0                    0.000000  0.000000  0.000000       0.000000  0.000000
# Free                 2.022114  4.442674  0.597669       3.586015  2.261181
# Paid                 3.500000  1.750000  0.000000       3.375000  0.875000
#
# Category  EDUCATION  ...  PERSONALIZATION  PHOTOGRAPHY  PRODUCTIVITY  \
# Type                 ...
# 0          0.000000  ...         0.000000      0.00000      0.000000
# Free       1.514095  ...         3.077996      3.11784      3.944616
# Paid       0.500000  ...        10.375000      2.75000      3.500000
#
# Category  SHOPPING    SOCIAL    SPORTS     TOOLS  TRAVEL_AND_LOCAL  \
# Type
# ...

# %% [markdown]
# <div style="background-color:orange;">
#     <h1 align="center"><ins>Normalize data by columns</ins></h1>
# </div>

# %%
pd.crosstab( googleplay_data.Type, googleplay_data.Category, normalize = "columns" )
# Out:
# Category  1.9  ART_AND_DESIGN  AUTO_AND_VEHICLES  BEAUTY  BOOKS_AND_REFERENCE  \
# Type
# 0         1.0        0.000000           0.000000     0.0             0.000000
# Free      0.0        0.953846           0.964706     1.0             0.878788
# Paid      0.0        0.046154           0.035294     0.0             0.121212
#
# Category  BUSINESS  COMICS  COMMUNICATION    DATING  EDUCATION  ...  \
# Type                                                            ...
# 0         0.000000     0.0       0.000000  0.000000   0.000000  ...
# Free      0.969565     1.0       0.930233  0.970085   0.974359  ...
# Paid      0.030435     0.0       0.069767  0.029915   0.025641  ...
#
# Category  PERSONALIZATION  PHOTOGRAPHY  PRODUCTIVITY  SHOPPING    SOCIAL  \
# Type
# 0                0.000000     0.000000      0.000000  0.000000  0.000000
# Free             0.788265     0.934328      0.933962  0.992308  0.989831
# Paid             0.211735     0.065672      0.066038  0.007692  0.010169
#
# ...

# %% [markdown]
# <div style="background-color:red;">
#     <h1 align="center"><ins>Normalize data at all</ins></h1>
# </div>

# %%
pd.crosstab( googleplay_data.Type, googleplay_data.Category, normalize = "all" )
# Out:
# Category       1.9  ART_AND_DESIGN  AUTO_AND_VEHICLES    BEAUTY  \
# Type
# 0         0.000092        0.000000           0.000000  0.000000
# Free      0.000000        0.005720           0.007565  0.004889
# Paid      0.000000        0.000277           0.000277  0.000000
#
# Category  BOOKS_AND_REFERENCE  BUSINESS    COMICS  COMMUNICATION    DATING  \
# Type
# 0                    0.000000  0.000000  0.000000       0.000000  0.000000
# Free                 0.018727  0.041144  0.005535       0.033210  0.020941
# Paid                 0.002583  0.001292  0.000000       0.002491  0.000646
#
# Category  EDUCATION  ...  PERSONALIZATION  PHOTOGRAPHY  PRODUCTIVITY  \
# Type                 ...
# 0          0.000000  ...         0.000000     0.000000      0.000000
# Free       0.014022  ...         0.028506     0.028875      0.036531
# Paid       0.000369  ...         0.007657     0.002030      0.002583
#
# Category  SHOPPING    SOCIAL    SPORTS     TOOLS  TRAVEL_AND_LOCAL  \
# Type
# ...

# %% [markdown]
# <div style="background-color:Baby pink;">
#     <h1></h1>
# </div>

# %% [markdown]
# <img src = https://mobilekomak.com/howto/wp-content/uploads/2016/12/google-play-store-problems-10.jpg>

# %% [markdown]
# <div style="background-color:brown;">
#     <h1 align="center"><ins>list of rating below 1</ins></h1>
# </div>

# %%
below_1_Rating = googleplay_data[ googleplay_data.Rating <= 1 ]

# %%
below_1_Rating[0:5]
# Out:
#                                    App Category  Rating Reviews  Size  \
# 625            House party - live chat   DATING     1.0       1  9.2M
# 4127                 Speech Therapy: F   FAMILY     1.0       1   16M
# 5151                     Clarksburg AH  MEDICAL     1.0       1   28M
# 5978     Truck Driving Test Class 3 BC   FAMILY     1.0       1  2.0M
# 6319  BJ Bridge Standard American 2018     GAME     1.0       1  4.9M
#
#      Installs  Type  Price Content Rating     Genres     Last Updated  \
# 625       10+  Free      0     Mature 17+     Dating    July 31, 2018
# 4127      10+  Paid  $2.99       Everyone  Education  October 7, 2016
# 5151      50+  Free      0       Everyone    Medical      May 1, 2017
# 5978      50+  Paid  $1.49       Everyone  Education    April 9, 2012
# 6319   1,000+  Free      0       Everyone       Card     May 21, 2018
#
#       Current Ver   Android Ver
# 625          3.52  4.0.3 and up
# 4127          1.0  2.3.3 and up
# ...

# %% [markdown]
# <div style="background-color:pink;">
#     <h1 align="center"><ins>number of rating below 1</ins></h1>
# </div>

# %%
len(below_1_Rating)
# Out:
# 16

# %% [markdown]
# <div style="background-color:green;">
#     <h1 align="center"><ins>name of App & catefort & price of rating below 1</ins></h1>
# </div>

# %%
googleplay_data[ googleplay_data.Rating <= 1 ][["App","Category","Price"]]
# Out:
#                                                     App       Category  Price
# 625                             House party - live chat         DATING      0
# 4127                                  Speech Therapy: F         FAMILY  $2.99
# 5151                                      Clarksburg AH        MEDICAL      0
# 5978                      Truck Driving Test Class 3 BC         FAMILY  $1.49
# 6319                   BJ Bridge Standard American 2018           GAME      0
# 6490                                             MbH BM        MEDICAL      0
# 7144                                      CB Mobile Biz        FINANCE      0
# 7383                                     Thistletown CI   PRODUCTIVITY      0
# 7427                                     CJ DVD Rentals  COMMUNICATION      0
# 7806                                        CR Magazine       BUSINESS      0
# 7926                               Tech CU Card Manager        FINANCE      0
# ...

# %% [markdown]
# <div style="background-color:purple;">
#     <h1 align="center"><ins>price of rating below 1</ins></h1>
# </div>

# %%
googleplay_data[ googleplay_data.Rating <= 1 ]["Price"].value_counts( )
# Out:
# 0        14
# $2.99     1
# $1.49     1
# Name: Price, dtype: int64

# %%
googleplay_data[ googleplay_data.Rating <= 1 ]["Price"].value_counts( normalize = True )
# Out:
# 0        0.8750
# $2.99    0.0625
# $1.49    0.0625
# Name: Price, dtype: float64

# %% [markdown]
# <div style="background-color:Blue bell;">
#     <h1 align="center"><ins>Programs with the name of SMS</ins></h1>
# </div>

# %%
googleplay_data[ googleplay_data.App.str.contains("SMS") ]
# Out:
#                                                      App           Category  \
# 90                                              SMS Park  AUTO_AND_VEHICLES
# 337                                    Messenger for SMS      COMMUNICATION
# 395           GO SMS Pro - Messenger, Free Themes, Emoji      COMMUNICATION
# 397                             Messaging+ SMS, MMS Free      COMMUNICATION
# 398                                            chomp SMS      COMMUNICATION
# 400                                             Text SMS      COMMUNICATION
# 405                        mysms SMS Text Messaging Sync      COMMUNICATION
# 449    Truecaller: Caller ID, SMS spam blocking & Dialer      COMMUNICATION
# 2581   Family GPS tracker KidControl + GPS by SMS Loc...             SOCIAL
# 2591   Free phone calls, free texting SMS on free number             SOCIAL
# 3501                              Pushbullet - SMS on PC       PRODUCTIVITY
# ...

# %% [markdown]
# <div style="background-color:orange;">
#     <h1 align="center"><ins>Unique data in each columns</ins></h1>
# </div>

# %%
googleplay_data.Type.unique()
# Out:
# array(['Free', 'Paid', nan, '0'], dtype=object)

# %% [markdown]
# <div style="background-color:red;">
#     <h1 align="center"><ins>print App name & category & android version of rating below 1</ins></h1>
# </div>

# %%
googleplay_data[ ( googleplay_data.Rating <= 2 )][['App','Category','Android Ver']][5:15]
# Out:
#                                  App        Category   Android Ver
# 4010     Bridge-C - Get More Storage           TOOLS    6.0 and up
# 4127               Speech Therapy: F          FAMILY  2.3.3 and up
# 4161                     G-Playlists           TOOLS  4.0.3 and up
# 4522            Q-Tech Companion App  FOOD_AND_DRINK    4.4 and up
# 4726                       W Box VMS   VIDEO_PLAYERS  2.3.3 and up
# 4904  Smart-AC Universal Remote Free          FAMILY    2.2 and up
# 4905         AC REMOTE UNIVERSAL-PRO          FAMILY    2.2 and up
# 4906                Kenmore Smart AC       LIFESTYLE    4.4 and up
# 4925        A/C REFRIGERANT CAPACITY        BUSINESS    4.1 and up
# 4995               ESS Mobile for AE    PRODUCTIVITY    3.0 and up

# %% [markdown]
# <div style="background-color:yellow;">
#     <h1 align="center"><ins>print App name & category & android version of rating is null</ins></h1>
# </div>

# %%
googleplay_data[ googleplay_data.Rating.isnull() ][['App','Category','Android Ver']][0:5]
# Out:
#                                      App        Category Android Ver
# 23                Mcqueen Coloring pages  ART_AND_DESIGN  4.1 and up
# 113            Wrinkles and rejuvenation          BEAUTY  3.0 and up
# 123               Manicure - nail design          BEAUTY  4.1 and up
# 126         Skin Care and Natural Beauty          BEAUTY  4.1 and up
# 129  Secrets of beauty, youth and health          BEAUTY  2.3 and up

# %%
googleplay_data[googleplay_data.isnull()]
# Out:
#        App Category  Rating Reviews Size Installs Type Price Content Rating  \
# 0      NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
# 1      NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
# 2      NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
# 3      NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
# 4      NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
# ...    ...      ...     ...     ...  ...      ...  ...   ...            ...
# 10836  NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
# 10837  NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
# 10838  NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
# 10839  NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
# 10840  NaN      NaN     NaN     NaN  NaN      NaN  NaN   NaN            NaN
#
#       Genres Last Updated Current Ver Android Ver
# ...

# %%
googleplay_data[-googleplay_data.Rating.isnull()]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# <div style="background-color:orange;">
#     <h1 align="center"><ins>print App name & category & android version of rating is not null</ins></h1>
# </div>

# %%
googleplay_data[ -googleplay_data.Rating.isnull() ][['App','Category','Android Ver']][0:5]
# Out:
#                                                  App        Category  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                Coloring book moana  ART_AND_DESIGN
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# <div style="background-color:yellow;">
#     <h1 align="center"><ins>group data by category and get Average of them raiting</ins></h1>
# </div>

# %%
googleplay_data.groupby( 'Category' )['Rating'].mean()[0:20]
# Out:
# Category
# 1.9                    19.000000
# ART_AND_DESIGN          4.358065
# AUTO_AND_VEHICLES       4.190411
# BEAUTY                  4.278571
# BOOKS_AND_REFERENCE     4.346067
# BUSINESS                4.121452
# COMICS                  4.155172
# COMMUNICATION           4.158537
# DATING                  3.970769
# EDUCATION               4.389032
# ENTERTAINMENT           4.126174
# EVENTS                  4.435556
# FAMILY                  4.192272
# FINANCE                 4.131889
# FOOD_AND_DRINK          4.166972
# GAME                    4.286326
# HEALTH_AND_FITNESS      4.277104
# HOUSE_AND_HOME          4.197368
# LIBRARIES_AND_DEMO      4.178462
# LIFESTYLE               4.094904
# Name: Rating, dtype: float64

# %% [markdown]
# <div style="background-color:red;">
#     <h1 align="center"><ins>group data by category and get Average of them raiting (in data forme)</ins></h1>
# </div>

# %%
googleplay_data.groupby( 'Category' )['Rating'].mean().reset_index()[0:20]
# Out:
#                Category     Rating
# 0                   1.9  19.000000
# 1        ART_AND_DESIGN   4.358065
# 2     AUTO_AND_VEHICLES   4.190411
# 3                BEAUTY   4.278571
# 4   BOOKS_AND_REFERENCE   4.346067
# 5              BUSINESS   4.121452
# 6                COMICS   4.155172
# 7         COMMUNICATION   4.158537
# 8                DATING   3.970769
# 9             EDUCATION   4.389032
# 10        ENTERTAINMENT   4.126174
# 11               EVENTS   4.435556
# 12               FAMILY   4.192272
# 13              FINANCE   4.131889
# 14       FOOD_AND_DRINK   4.166972
# 15                 GAME   4.286326
# 16   HEALTH_AND_FITNESS   4.277104
# 17       HOUSE_AND_HOME   4.197368
# 18   LIBRARIES_AND_DEMO   4.178462
# 19            LIFESTYLE   4.094904

# %% [markdown]
# <div style="background-color:pink;">
#     <h1 align="center"><ins>group data by category and Current Ver and get Average of them raiting(in data forme)</ins></h1>
# </div>

# %%
googleplay_data.groupby( ['Category', 'Current Ver'] )['Rating'].mean().reset_index()[0:20]
# Out:
#           Category Current Ver  Rating
# 0              1.9  4.0 and up  19.000
# 1   ART_AND_DESIGN           1   4.150
# 2   ART_AND_DESIGN         1.0   4.360
# 3   ART_AND_DESIGN       1.0.0   4.475
# 4   ART_AND_DESIGN      1.0.15   4.400
# 5   ART_AND_DESIGN       1.0.2   4.900
# 6   ART_AND_DESIGN       1.0.4   4.500
# 7   ART_AND_DESIGN       1.0.8   4.700
# 8   ART_AND_DESIGN       1.0.9   4.700
# 9   ART_AND_DESIGN        1.03   4.100
# 10  ART_AND_DESIGN         1.1   4.050
# 11  ART_AND_DESIGN       1.1.0   4.200
# 12  ART_AND_DESIGN       1.1.1   4.800
# 13  ART_AND_DESIGN       1.1.3   4.700
# 14  ART_AND_DESIGN         1.2   4.150
# 15  ART_AND_DESIGN       1.2.2   4.700
# 16  ART_AND_DESIGN       1.2.3   4.400
# 17  ART_AND_DESIGN       1.2.4   4.700
# 18  ART_AND_DESIGN         1.3   4.700
# 19  ART_AND_DESIGN        1.46   3.800

# %% [markdown]
# <div style="background-color:brown;">
#     <h1 align="center"><ins>Sort by rating(Ascending)</ins></h1>
# </div>

# %%
googleplay_data.sort_values('Rating',ascending=True)
# Out:
#                                                     App             Category  \
# 8820                                     DS Creator 2.0                TOOLS
# 7144                                      CB Mobile Biz              FINANCE
# 10400           Familial Hypercholesterolaemia Handbook              MEDICAL
# 10591  Lottery Ticket Checker - Florida Results & Lotto                TOOLS
# 5151                                      Clarksburg AH              MEDICAL
# ...                                                 ...                  ...
# 10824                                         Cardio-FR              MEDICAL
# 10825                                Naruto & Boruto FR               SOCIAL
# 10831                          payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10835                                          FR Forms             BUSINESS
# 10838                            Parkinson Exercices FR              MEDICAL
#
# ...

# %% [markdown]
# <div style="background-color:yellow;">
#     <h1 align="center"><ins>Sort by Reviews(Descending)</ins></h1>
# </div>

# %%
googleplay_data.sort_values( 'Reviews', ascending = False)
# Out:
#                                     App             Category  Rating Reviews  \
# 2989             GollerCepte Live Score               SPORTS     4.2    9992
# 4970       Ad Block REMOVER - NEED ROOT                TOOLS     3.3     999
# 2723                SnipSnap Coupon App             SHOPPING     4.2    9975
# 2705                SnipSnap Coupon App             SHOPPING     4.2    9975
# 3079  US Open Tennis Championships 2018               SPORTS     4.0    9971
# ...                                 ...                  ...     ...     ...
# 7217                          CE-STRONG               FAMILY     NaN       0
# 6492                   Anime Mod for BM  BOOKS_AND_REFERENCE     NaN       0
# 7221                  CE-SETRAM l’Appli   LIBRARIES_AND_DEMO     NaN       0
# 5480           Glanceable Ap Watch Face      PERSONALIZATION     NaN       0
# 4177                    G-NetReport Pro                TOOLS     NaN       0
#
# ...

# %% [markdown]
# <img src = "https://cinemativ.ir/wp-content/uploads/2020/07/GooglePlayStoreFix.jpg" width="500px" height="600px" >

# %% [markdown]
# <div style="background-color:Green;">
#     <h1 align="center"><ins>loc & iloc</ins></h1>
# </div>

# %%
googleplay_data.iloc[[0,1,2],[0,1,2]]
# Out:
#                                                  App        Category  Rating
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7

# %%
googleplay_data.iloc[:,[0,1,2]]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating
# 0         4.1
# ...

# %%
googleplay_data.iloc[:,[0]]
# Out:
#                                                      App
# 0         Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                    Coloring book moana
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                  Sketch - Draw & Paint
# 4                  Pixel Draw - Number Art Coloring Book
# ...                                                  ...
# 10836                                   Sya9a Maroc - FR
# 10837                   Fr. Mike Schmitz Audio Teachings
# 10838                             Parkinson Exercices FR
# 10839                      The SCP Foundation DB fr nn5n
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
# [10841 rows x 1 columns]

# %%
x=[True,False,False,False,True,True,False,False,False,True,False,False,True]
googleplay_data.iloc[:,x]
# Out:
#                                                      App                Size  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook                 19M
# 1                                    Coloring book moana                 14M
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...                8.7M
# 3                                  Sketch - Draw & Paint                 25M
# 4                  Pixel Draw - Number Art Coloring Book                2.8M
# ...                                                  ...                 ...
# 10836                                   Sya9a Maroc - FR                 53M
# 10837                   Fr. Mike Schmitz Audio Teachings                3.6M
# 10838                             Parkinson Exercices FR                9.5M
# 10839                      The SCP Foundation DB fr nn5n  Varies with device
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology                 19M
#
# ...

# %%
googleplay_data2 = pd.read_csv(r"E:\Course\utech AI\ML\Project\Google play\googleplaystore.csv",index_col="App")

# %%
googleplay_data2
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# Parkinson Exercices FR                                          MEDICAL
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating Reviews  \
# App
# ...

# %%
googleplay_data2.loc["Photo Editor & Candy Camera & Grid & ScrapBook"]
# Out:
# Category           ART_AND_DESIGN
# Rating                        4.1
# Reviews                       159
# Size                          19M
# Installs                  10,000+
# Type                         Free
# Price                           0
# Content Rating           Everyone
# Genres               Art & Design
# Last Updated      January 7, 2018
# Current Ver                 1.0.0
# Android Ver          4.0.3 and up
# Name: Photo Editor & Candy Camera & Grid & ScrapBook, dtype: object

# %%
googleplay_data2.loc["Photo Editor & Candy Camera & Grid & ScrapBook","Genres"]
# Out:
# 'Art & Design'

# %%
googleplay_data2.loc[ (googleplay_data2.Category=="ART_AND_DESIGN") & (googleplay_data2.Genres=="Art & Design") ]
# Out:
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
# Paper flowers instructions                          ART_AND_DESIGN     4.4
# Smoke Effect Photo Maker - Smoke Editor             ART_AND_DESIGN     3.8
# Infinite Painter                                    ART_AND_DESIGN     4.1
# Garden Coloring Book                                ART_AND_DESIGN     4.4
# Text on Photo - Fonteee                             ART_AND_DESIGN     4.4
# Name Art Photo Editor - Focus n Filters             ART_AND_DESIGN     4.4
# Tattoo Name On My Photo Editor                      ART_AND_DESIGN     4.2
# Mandala Coloring Book                               ART_AND_DESIGN     4.6
# ...

# %% [markdown]
# <div style="background-color:yellow;">
#     <h1 align="center"><ins>Query</ins></h1>
# </div>

# %%
googleplay_data.query('Category=="ART_AND_DESIGN" and Genres=="Art & Design"')
# Out:
#                                                     App        Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 5                            Paper flowers instructions  ART_AND_DESIGN
# 6               Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN
# 7                                      Infinite Painter  ART_AND_DESIGN
# 8                                  Garden Coloring Book  ART_AND_DESIGN
# 10                              Text on Photo - Fonteee  ART_AND_DESIGN
# 11              Name Art Photo Editor - Focus n Filters  ART_AND_DESIGN
# 12                       Tattoo Name On My Photo Editor  ART_AND_DESIGN
# 13                                Mandala Coloring Book  ART_AND_DESIGN
# 14      3D Color Pixel by Number - Sandbox Art Coloring  ART_AND_DESIGN
# ...

# %%
googleplay_data.Genres.unique()
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Art & Design;Action & Adventure',
#        'Auto & Vehicles', 'Beauty', 'Books & Reference', 'Business',
#        'Comics', 'Comics;Creativity', 'Communication', 'Dating',
#        'Education;Education', 'Education', 'Education;Creativity',
#        'Education;Music & Video', 'Education;Action & Adventure',
#        'Education;Pretend Play', 'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
# ...

# %%
googleplay_data[(googleplay_data['Category']=='ART_AND_DESIGN') & (googleplay_data['Genres']=='Art & Design')]
# Out:
#                                                     App        Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 5                            Paper flowers instructions  ART_AND_DESIGN
# 6               Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN
# 7                                      Infinite Painter  ART_AND_DESIGN
# 8                                  Garden Coloring Book  ART_AND_DESIGN
# 10                              Text on Photo - Fonteee  ART_AND_DESIGN
# 11              Name Art Photo Editor - Focus n Filters  ART_AND_DESIGN
# 12                       Tattoo Name On My Photo Editor  ART_AND_DESIGN
# 13                                Mandala Coloring Book  ART_AND_DESIGN
# 14      3D Color Pixel by Number - Sandbox Art Coloring  ART_AND_DESIGN
# ...

# %% [markdown]
# <div style="background-color:pink;">
#     <h1 align="center"><ins>seaborn</ins></h1>
# </div>

# %%
type(googleplay_data)
# Out:
# pandas.core.frame.DataFrame

# %%
googleplay_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
sns.displot(googleplay_data, x="Rating")

# %%
sns.displot(googleplay_data, x="Rating" , bins=6)

# %%
sns.displot(googleplay_data, x="Rating" , discrete=True)

# %%
sns.displot(googleplay_data, x="Rating" , shrink=2)

# %%
sns.displot(googleplay_data, x="Rating" , kind="kde")

# %%
sns.color_palette("pastel")
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %%
sns.catplot(x="Rating", y="Category", data=googleplay_data)

# %%
sns.catplot(x="Rating", y="Category", jitter=False ,data=googleplay_data)

# %%
sns.catplot(x="Type", y="Rating", data=googleplay_data)

# %%
sns.catplot(x="Type", y="Rating", kind="box" , data=googleplay_data)

# %%
sns.catplot(x="Type", y="Rating", kind="boxen" , data=googleplay_data)

# %%
sns.catplot(x="Type", y="Rating", kind="violin" , data=googleplay_data)

# %%
sns.catplot(x="Type", y="Rating", kind="bar" , data=googleplay_data)

# %%
sns.catplot(x="Type", y="Rating", kind="point" , data=googleplay_data)

# %%
sns.catplot(x="Type", kind="count" , data=googleplay_data)

# %%
sns.relplot(x="Type", y="Rating" , data=googleplay_data)

# %%
sns.set_theme(style="darkgrid")
sns.relplot(x="Type", y="Rating", data=googleplay_data)

# %%
sns.relplot(x="Type", y="Rating" , style="Rating" , data=googleplay_data)

# %%
sns.relplot(x="Type", y="Rating" , data=googleplay_data)

# %% [markdown]
# <div style="background-color:Blue;">
#     <h1 align="center"><ins>FacetGrid</ins></h1>
# </div>

# %%
sns.FacetGrid(googleplay_data)

# %%
sns.FacetGrid(googleplay_data , col="Type" , row="Rating")

# %%
g = sns.FacetGrid(googleplay_data , col="Type" , row="Rating")
g.map(sns.scatterplot, "Type", "Rating")

# %%
g = sns.FacetGrid(googleplay_data , col="Rating" , height=3.5, aspect=.65)
g.map(sns.histplot, "Price")

# %% [markdown]
# ## Send Me the Result (on Telegram)
